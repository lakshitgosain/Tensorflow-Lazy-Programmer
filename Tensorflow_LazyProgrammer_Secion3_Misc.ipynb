# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitgosain/Tensorflow-Lazy-Programmer/blob/main/Tensorflow_LazyProgrammer_Secion3_Misc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The Neuron

# %%
#feature Importance. Magnitude and direction of the input will decide the effect of the input to the Output Value.

#how is this related to neuron?
- A neuron is a cell in the brain. It can talk to other neurons using signals.
- A single Neuron takes input from lot of ther neurons.

#Neuron Connections.
Not all connections are made equal.
Some are excitatory(+) and some are inhibitory(-)


-Action potential is the signla passed upon a neuron
- We can think of the as a binary outcome. THink of it in a way that is the potential is more than a value then send a signla else dont send a signal at all.
- It's like a binary decision. You either spike or dont.
# Out:
#   File "<ipython-input-1-6d276df6b323>", line 4
#     - A neuron is a cell in the brain. It can talk to other neurons using signals.
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![neuron.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **How Does a Model Learn**

# %% [markdown]
# The Error Function =Loss=Cost
# MSE=Mean Squared Error
# y^i=mxi+b
#
# ## MSE=1/N summation(yi-y^i)\\

# %% [markdown]
# How to Minimize the Cost
# We can find the min/Max of the function by finding the derivative of the slopw is 0 .

# %% [markdown]
# Even in Multidimensional . The Derivate is called a gradient
# To solve for model Parameters, we find the gradient and set it to 0.

# %%
# Out:
#   File "<ipython-input-2-840ce1759c51>", line 1
#     How to Minimize the Cost
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Tensorflow uses Automatic Differentiation for Finding the gradient for all your weights.

# %% [markdown]
# Gradient Descent
#
# If all we have to do is find the gradient and set it to 0, then why are we using an iterative Process?
# Why do we use epochs and why do we check for convergance
#
# Most of the time it's not possible to solve for 0
#
# We start at a randomly initlaized point , and start reducing the value
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Making Predictions##

# %% [markdown]
# Being Continued in the Linear Classification Notebook of rhti section

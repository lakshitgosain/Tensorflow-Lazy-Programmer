# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshitgosain/Tensorflow-Lazy-Programmer/blob/main/Tensorflow_LazyProgrammer_section4_ArtificialNeuralNw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Feed Forward Neural Networks

# %%
#Artificial Neural Networds
#Where do ANNs Come from

# %% [markdown]
# #Artificial Neural Networds
# #Where do ANNs Come from
# 1. The name neural networks is derived from the neuro
# 2. neurons are cells in your brain that extend throughout your nervous system
# 3. probably obvious, your brain is what you use to think
# 4. Neurons communicate with each other via electrical/chemical signals
# 5. these simple intercations form all of your thoughts and actions
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #It's going in the forward direction
#
# Key Insight :
# - We can stack more layers of NetwordsA chain of neurons can be created
# - We can model the brain as a uniform Structure
# - There is no difference b/w neurons in different parts of the brain. THey all work the same way so we can continue addin more layers

# %% [markdown]
# 2 Important ways to extend the single neurn
#  - The same inputs can be fed to different multiple neurons, each calculating somthing different(more neurons per layer) - THis makes the n/w to make it wide
#  - Neurons in one layer can act as input to another layer (Makes the network Deep)
#
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
One way to do it is feature engineering .
Suppose the salary is quadratic function of YOE. 
THis is still linear regression. We've just engineered mew input features

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
The Problem is we can have too many possibilities of features. What if we have 3-4-5 input features.
# Out:
#   File "<ipython-input-2-d2a53943e892>", line 1
#     The Problem is we can have too many possibilities of features. What if we have 3-4-5 input features.
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The below can be used to create a linear boundary or for Regression Models

# %% [markdown]
# ![image.png](data:image/png;base64,...)
